# %% [markdown]
# # Higgs Boson - Predicting
#
# (example from xgboost docs)
#
# ## [Link](https://www.kaggle.com/c/higgs-boson)

# %%
import numpy as np
import xgboost as xgb
import pandas as pd

# %%
modelfile = 'higgs.model'
threshold_ratio = 0.15

# %%
dtest = np.loadtxt('data/higgs/test.csv', delimiter=',', skiprows=1 )
data   = dtest[:,1:31]
idx = dtest[:,0]

# %% [markdown]
# Predict!

# %%
xgmat = xgb.DMatrix( data, missing = -999.0 )
bst = xgb.Booster({'nthread':16}, model_file = modelfile)
ypred = bst.predict( xgmat )

# %%
res  = [ ( int(idx[i]), ypred[i] ) for i in range(len(ypred)) ]

rorder = {}
for k, v in sorted( res, key = lambda x:-x[1] ):
    rorder[ k ] = len(rorder) + 1

# %%
ntop = int( threshold_ratio * len(rorder ) )
fo = open('higgs.pred.csv', 'w')
nhit = 0
ntot = 0
fo.write('EventId,RankOrder,Class\n')
for k, v in res:
    if rorder[k] <= ntop:
        lb = 's'
        nhit += 1
    else:
        lb = 'b'
    # change output rank order to follow Kaggle convention
    fo.write('%s,%d,%s\n' % ( k,  len(rorder)+1-rorder[k], lb ) )
    ntot += 1
fo.close()

# %%
pd.read_csv('higgs.pred.csv')
# Out:
#         EventId  RankOrder Class
# 0        350000      12429     b
# 1        350001     239692     b
# 2        350002     351852     b
# 3        350003     492038     s
# 4        350004      93743     b
# 5        350005     155334     b
# 6        350006     202380     b
# 7        350007      31079     b
# 8        350008      97704     b
# 9        350009     496777     s
# 10       350010     150278     b
# 11       350011     208182     b
# 12       350012     373279     b
# 13       350013     237856     b
# 14       350014      34334     b
# 15       350015      35523     b
# 16       350016     204430     b
# 17       350017      56520     b
# 18       350018     132555     b
# 19       350019     432850     b
# 20       350020     155321     b
# 21       350021      73254     b
# 22       350022     247038     b
# 23       350023     142407     b
# 24       350024     195399     b
# 25       350025     427873     b
# 26       350026     400131     b
# ...
